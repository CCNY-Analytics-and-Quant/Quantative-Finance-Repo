# %%
# packages
import pandas as pd
import yfinance as yf
import numpy as np

import seaborn as sn
import matplotlib.pyplot as plt

# %%
# Step 1: Choose seven (7) assets
tickers = ["NVDA", "NFLX", "GME", "BB", "NOK", "AMZN", "TSLA"]
tickers
# Out:
# ['NVDA', 'NFLX', 'GME', 'BB', 'NOK', 'AMZN', 'TSLA']

# %%
# Step 2: Retrieve daily open or close data on your assets for the previous 2 years
df = yf.download(tickers, period='2y')

adj_close = df['Adj Close']
returns = adj_close.pct_change()
returns
# Out:
# [*********************100%%**********************]  7 of 7 completed
#                 AMZN        BB       GME      NFLX       NOK      NVDA  \
# Date
# 2021-10-18       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-10-19 -0.000751  0.140594  0.004139  0.001615 -0.010152  0.003060
# 2021-10-20 -0.008446 -0.009549 -0.012153 -0.021690  0.011966 -0.008389
# 2021-10-21  0.005842 -0.009641 -0.015229  0.044822  0.005068  0.026648
# 2021-10-22 -0.028955 -0.033628 -0.065544  0.017791 -0.011765  0.001498
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-10  0.009512  0.002778  0.038961 -0.032724  0.011236  0.011596
# 2023-10-11  0.018150 -0.005540 -0.011250 -0.019795 -0.008333  0.022010
# 2023-10-12  0.003793 -0.027855 -0.046144 -0.012926  0.000000  0.002970
# 2023-10-13 -0.019195 -0.005731 -0.011266 -0.015282 -0.016807 -0.031612
# 2023-10-16  0.020418  0.074928 -0.021448  0.018071  0.024217  0.006126
#
#                 TSLA
# Date
# 2021-10-18       NaN
# 2021-10-19 -0.006712
# 2021-10-20  0.001770
# 2021-10-21  0.032571
# 2021-10-22  0.017539
# ...              ...
# 2023-10-10  0.015212
# 2023-10-11 -0.002390
# 2023-10-12 -0.015666
# 2023-10-13 -0.029938
# 2023-10-16  0.004699
#
# [502 rows x 7 columns]

# %%
returns = np.log(1 + adj_close.pct_change())
returns
# Out:
#                 AMZN        BB       GME      NFLX       NOK      NVDA  \
# Date
# 2021-10-18       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-10-19 -0.000752  0.131549  0.004131  0.001613 -0.010204  0.003055
# 2021-10-20 -0.008482 -0.009595 -0.012227 -0.021929  0.011895 -0.008425
# 2021-10-21  0.005825 -0.009687 -0.015346  0.043846  0.005055  0.026299
# 2021-10-22 -0.029382 -0.034207 -0.067791  0.017634 -0.011834  0.001497
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-10  0.009467  0.002774  0.038221 -0.033272  0.011173  0.011530
# 2023-10-11  0.017987 -0.005556 -0.011314 -0.019994 -0.008368  0.021771
# 2023-10-12  0.003786 -0.028250 -0.047243 -0.013010  0.000000  0.002965
# 2023-10-13 -0.019381 -0.005747 -0.011330 -0.015400 -0.016950 -0.032122
# 2023-10-16  0.020212  0.072254 -0.021681  0.017910  0.023928  0.006107
#
#                 TSLA
# Date
# 2021-10-18       NaN
# 2021-10-19 -0.006734
# 2021-10-20  0.001769
# 2021-10-21  0.032052
# 2021-10-22  0.017387
# ...              ...
# 2023-10-10  0.015097
# 2023-10-11 -0.002393
# 2023-10-12 -0.015790
# 2023-10-13 -0.030395
# 2023-10-16  0.004688
#
# [502 rows x 7 columns]

# %%
# Step 3: Calculate the mean, variance, and correlation matrix for all assets
table = pd.DataFrame(index=tickers)

table['Mean'] = returns.mean()
table['Variance'] = returns.var()

# %%
# Displays table result - mean and variance 
table
# Out:
#           Mean  Variance
# NVDA  0.001444  0.001337
# NFLX -0.001130  0.001354
# GME  -0.002312  0.002945
# BB   -0.001988  0.001290
# NOK  -0.000900  0.000389
# AMZN -0.000526  0.000709
# TSLA -0.000278  0.001570

# %%
# Displays table result - correlation
corr_matrix = returns.corr()
corr_matrix
# Out:
#           AMZN        BB       GME      NFLX       NOK      NVDA      TSLA
# AMZN  1.000000  0.474945  0.348786  0.513923  0.448105  0.606252  0.486815
# BB    0.474945  1.000000  0.434279  0.409806  0.412218  0.466818  0.476609
# GME   0.348786  0.434279  1.000000  0.251652  0.286586  0.411951  0.462159
# NFLX  0.513923  0.409806  0.251652  1.000000  0.317184  0.458157  0.434360
# NOK   0.448105  0.412218  0.286586  0.317184  1.000000  0.475161  0.408880
# NVDA  0.606252  0.466818  0.411951  0.458157  0.475161  1.000000  0.572415
# TSLA  0.486815  0.476609  0.462159  0.434360  0.408880  0.572415  1.000000

# %%
plt.figure()
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Step 4: Calculate efficient frontier and optimal weights for your portfolio (Don’t forget the output!)

# %%
# Step 5: Use MatPlotLib or Seaborn libraries to graph the results (matrix and frontier)

# %%
# Step 6: Output the calculated optimal weighting (identify portfolio weightings for optimum Sharpe Ratio) along with the efficient frontier and correlation matrix charts. Output to a saved file.
