# %%
import yfinance as yf
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
tickers = ["NVDA", "META", "AAPL", "MSFT", "TSM", "AMD", "AVGO"]
etfs = ["SPY", "IWM", "DIA"]
assets = tickers + etfs

data = yf.download(assets, period = '2y')
returns = data['Adj Close'].pct_change().dropna()
# Out:
# [*********************100%%**********************]  10 of 10 completed

# %%
# Step 2: Retrieve daily open or close data on your assets for the previous 2 years

# %%
data['Adj Close']
# Out:
#                   AAPL         AMD        AVGO         DIA         IWM  \
# Date
# 2021-10-13  139.298431  109.160004  458.619629  330.885712  216.311462
# 2021-10-14  142.115845  111.989998  470.524567  335.927582  219.518692
# 2021-10-15  143.183472  112.120003  475.867157  339.620636  218.828644
# 2021-10-18  144.873917  116.430000  475.971161  339.283936  218.702286
# 2021-10-19  147.058655  116.330002  482.618652  341.170197  219.518692
# ...                ...         ...         ...         ...         ...
# 2023-10-06  177.490005  107.239998  845.260010  334.100006  173.000000
# 2023-10-09  178.990005  106.970001  855.880005  336.089996  174.000000
# 2023-10-10  178.389999  109.010002  858.409973  337.450012  175.970001
# 2023-10-11  179.800003  108.309998  874.559998  338.029999  175.669998
# 2023-10-12  180.710007  108.790001  905.599976  336.269989  171.699997
#
#                   META        MSFT        NVDA         SPY         TSM
# Date
# 2021-10-13  324.540009  291.037354  209.094391  422.049011  105.664131
# 2021-10-14  328.529999  297.362732  217.153000  429.148132  108.142883
# 2021-10-15  324.760010  298.796783  218.311356  432.416443  110.352631
# 2021-10-18  335.339996  301.821960  221.906265  433.696594  110.813797
# 2021-10-19  339.989990  302.745239  222.585312  437.042511  112.370216
# ...                ...         ...         ...         ...         ...
# 2023-10-06  315.429993  327.260010  457.619995  429.540009   89.290001
# 2023-10-09  318.359985  329.820007  452.730011  432.290009   88.989998
# 2023-10-10  321.839996  328.390015  457.980011  434.540009   90.610001
# 2023-10-11  327.820007  332.420013  468.059998  436.320007   92.000000
# 2023-10-12  324.160004  331.160004  469.450012  433.660004   92.419998
#
# [503 rows x 10 columns]

# %%
returns
# Out:
#                 AAPL       AMD      AVGO       DIA       IWM      META  \
# Date
# 2021-10-14  0.020226  0.025925  0.025958  0.015237  0.014827  0.012294
# 2021-10-15  0.007512  0.001161  0.011355  0.010994 -0.003143 -0.011475
# 2021-10-18  0.011806  0.038441  0.000219 -0.000991 -0.000577  0.032578
# 2021-10-19  0.015080 -0.000859  0.013966  0.005560  0.003733  0.013867
# 2021-10-20  0.003361  0.000516 -0.001959  0.004429  0.006641  0.002324
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-06  0.014750  0.042076  0.025975  0.008847  0.009629  0.034909
# 2023-10-09  0.008451 -0.002518  0.012564  0.005956  0.005780  0.009289
# 2023-10-10 -0.003352  0.019071  0.002956  0.004047  0.011322  0.010931
# 2023-10-11  0.007904 -0.006421  0.018814  0.001719 -0.001705  0.018581
# 2023-10-12  0.005061  0.004432  0.035492 -0.005207 -0.022599 -0.011165
#
#                 MSFT      NVDA       SPY       TSM
# Date
# 2021-10-14  0.021734  0.038541  0.016821  0.023459
# 2021-10-15  0.004823  0.005334  0.007616  0.020434
# 2021-10-18  0.010125  0.016467  0.002960  0.004179
# 2021-10-19  0.003059  0.003060  0.007715  0.014045
# 2021-10-20 -0.002660 -0.008389  0.003928 -0.011713
# ...              ...       ...       ...       ...
# 2023-10-06  0.024737  0.024033  0.011873  0.025968
# 2023-10-09  0.007823 -0.010686  0.006402 -0.003360
# 2023-10-10 -0.004336  0.011596  0.005205  0.018204
# 2023-10-11  0.012272  0.022010  0.004096  0.015340
# 2023-10-12 -0.003790  0.002970 -0.006096  0.004565
#
# [502 rows x 10 columns]

# %%
# Step 3: Calculate the mean, variance, and correlation matrix for all assets

# %%
# Mean and Variance
table = pd.DataFrame(index=assets)
table['Mean'] = returns.mean()  # Calculating mean on returns
table['Variance'] = returns.var()  # Calculating variance on returns

table.round(4)  # Displaying the mean and variance table
# Out:
#         Mean  Variance
# NVDA  0.0023    0.0014
# META  0.0006    0.0012
# AAPL  0.0007    0.0004
# MSFT  0.0004    0.0004
# TSM  -0.0000    0.0005
# AMD   0.0006    0.0012
# AVGO  0.0016    0.0005
# SPY   0.0001    0.0002
# IWM  -0.0003    0.0002
# DIA   0.0001    0.0001

# %%
# Correlation Matrix
corr_matrix = returns.corr()  # Calculating correlation matrix on returns
print(corr_matrix.round(2))  # Displaying the correlation matrix

# Visualizing the Correlation Matrix
plt.figure(figsize=(10, 8))
sn.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
#       AAPL   AMD  AVGO   DIA   IWM  META  MSFT  NVDA   SPY   TSM
# AAPL  1.00  0.62  0.66  0.75  0.70  0.56  0.73  0.65  0.84  0.58
# AMD   0.62  1.00  0.66  0.60  0.66  0.52  0.66  0.82  0.72  0.68
# AVGO  0.66  0.66  1.00  0.67  0.66  0.48  0.64  0.71  0.75  0.62
# DIA   0.75  0.60  0.67  1.00  0.86  0.51  0.70  0.60  0.95  0.54
# IWM   0.70  0.66  0.66  0.86  1.00  0.56  0.63  0.66  0.90  0.59
# META  0.56  0.52  0.48  0.51  0.56  1.00  0.59  0.52  0.63  0.45
# MSFT  0.73  0.66  0.64  0.70  0.63  0.59  1.00  0.70  0.81  0.54
# NVDA  0.65  0.82  0.71  0.60  0.66  0.52  0.70  1.00  0.74  0.72
# SPY   0.84  0.72  0.75  0.95  0.90  0.63  0.81  0.74  1.00  0.64
# TSM   0.58  0.68  0.62  0.54  0.59  0.45  0.54  0.72  0.64  1.00

# %%
# Step 4: Calculate efficient frontier and optimal weights for your portfolio (Don’t forget the output!)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming `returns` DataFrame is already defined as before
num_portfolios = 10000
all_weights = np.zeros((num_portfolios, len(assets)))
ret_arr = np.zeros(num_portfolios)
vol_arr = np.zeros(num_portfolios)
sharpe_arr = np.zeros(num_portfolios)

np.random.seed(42)  # for reproducible results

for x in range(num_portfolios):
    # Weights
    weights = np.array(np.random.random(len(assets)))
    weights = weights/np.sum(weights)
    
    # Save weights
    all_weights[x,:] = weights
    
    # Expected return
    ret_arr[x] = np.sum( (returns.mean() * weights * 252))
    
    # Expected volatility
    vol_arr[x] = np.sqrt(np.dot(weights.T, np.dot(returns.cov()*252, weights)))
    
    # Sharpe Ratio
    sharpe_arr[x] = ret_arr[x]/vol_arr[x]

# Plotting the data
plt.figure(figsize=(12,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr, cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.title('Efficient Frontier with Monte Carlo Simulation')
plt.show()

# %%
# Step 5: Use MatPlotLib or Seaborn libraries to graph the results (matrix and frontier)

# %%
# Step 6: Output the calculated optimal weighting (identify portfolio weightings for optimum Sharpe Ratio)
# along with the efficient frontier and correlation matrix charts. Output to a saved file.
